# %% [markdown]
# <a href="https://colab.research.google.com/github/Della1122/Covid-19/blob/main/UAS_Della_Natallia_Covid_19_full_grouped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset country_wise_latest: Simple Exploratory Data Analysis (EDA)

# %%
import pandas as pd

# %%
#load package drive
from google.colab import drive

# %%
#memberikan akses kepada colab / Autorization
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#buat variabel jalur/dataset file dataset
dataset = '/content/drive/My Drive/dataset COVID 19/full_grouped.csv'

# %%
df = pd.read_csv('/content/drive/My Drive/dataset COVID 19/full_grouped.csv') # memuat file csv sebagai data frame

df.head() # tampilkan 5 baris pertama
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe
# 2           0              0                 Africa
# 3           0              0                 Europe
# 4           0              0                 Africa

# %%
# Menghapus kolom yang tidak diperlukan (columns='Date')
cols_to_drop = ['Date']
df.drop(columns=cols_to_drop, inplace=True)

# Menampilkan 5 baris pertama dari DataFrame
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan          0       0          0       0          0           0
# 1        Albania          0       0          0       0          0           0
# 2        Algeria          0       0          0       0          0           0
# 3        Andorra          0       0          0       0          0           0
# 4         Angola          0       0          0       0          0           0
#
#    New recovered             WHO Region
# 0              0  Eastern Mediterranean
# 1              0                 Europe
# 2              0                 Africa
# 3              0                 Europe
# 4              0                 Africa

# %%
df.shape # bentuk/dimensi dataset (baris,kolom)
# Out:
# (35156, 9)

# %% [markdown]
# Berarti ada 187 baris dan 6 kolom

# %%
df.columns # daftar nama kolom
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'WHO Region'],
#       dtype='object')

# %%
df.dtypes # tipe data untuk tiap kolom
# Out:
# Country/Region    object
# Confirmed          int64
# Deaths             int64
# Recovered          int64
# Active             int64
# New cases          int64
# New deaths         int64
# New recovered      int64
# WHO Region        object
# dtype: object

# %%
df.info() # informasi dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35156 entries, 0 to 35155
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  35156 non-null  object
#  1   Confirmed       35156 non-null  int64
#  2   Deaths          35156 non-null  int64
#  3   Recovered       35156 non-null  int64
#  4   Active          35156 non-null  int64
#  5   New cases       35156 non-null  int64
#  6   New deaths      35156 non-null  int64
#  7   New recovered   35156 non-null  int64
#  8   WHO Region      35156 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 2.4+ MB

# %%
# df.isnull().values.any()
df.isna().values.any() # mendeteksi keberadaan nilai kosong
# Out:
# False

# %%
# df[df.duplicated(keep=False)] # tampilkan seluruh baris dengan duplikasi
df[df.duplicated()] # tampilkan hanya baris duplikasi sekunder
# Out:
#        Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 187       Afghanistan          0       0          0       0          0
# 188           Albania          0       0          0       0          0
# 189           Algeria          0       0          0       0          0
# 190           Andorra          0       0          0       0          0
# 191            Angola          0       0          0       0          0
# ...               ...        ...     ...        ...     ...        ...
# 35117      Seychelles        114       0         39      75          0
# 35126           Spain     272421   28432     150376   93613          0
# 35135        Tanzania        509      21        183     305          0
# 35137     Timor-Leste         24       0          0      24          0
# 35152  Western Sahara         10       1          8       1          0
#
#        New deaths  New recovered             WHO Region
# 187             0              0  Eastern Mediterranean
# 188             0              0                 Europe
# 189             0              0                 Africa
# 190             0              0                 Europe
# 191             0              0                 Africa
# ...           ...            ...                    ...
# 35117           0              0                 Africa
# 35126           0              0                 Europe
# 35135           0              0                 Africa
# 35137           0              0        South-East Asia
# 35152           0              0                 Africa
#
# [11986 rows x 9 columns]

# %%
df.duplicated().value_counts() # hitung jumlah duplikasi data
# Out:
# False    23170
# True     11986
# dtype: int64

# %%
df.drop_duplicates(inplace=True) # menghapus duplikasi data
df.shape
# Out:
# (23170, 9)

# %%
df.describe() # deskripsi data
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  2.317000e+04   23170.000000  2.317000e+04  2.317000e+04  23170.000000
# mean   3.559004e+04    1858.923910  1.667900e+04  1.705212e+04    712.168839
# std    1.835346e+05    9081.777805  7.888082e+04  1.103681e+05   3679.199261
# min    0.000000e+00       0.000000  0.000000e+00 -2.000000e+00      0.000000
# 25%    1.920000e+02       3.000000  1.900000e+01  7.400000e+01      3.000000
# 50%    1.464000e+03      29.000000  4.545000e+02  5.500000e+02     27.000000
# 75%    1.113900e+04     260.000000  3.877000e+03  4.447500e+03    234.000000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  77255.000000
#
#          New deaths  New recovered
# count  23170.000000   23170.000000
# mean      28.226975     408.634355
# std      141.570775    2536.240184
# min    -1918.000000  -16298.000000
# 25%        0.000000       0.000000
# 50%        0.000000       6.000000
# 75%        5.000000      75.750000
# max     3887.000000  140050.000000

# %%
df.corr() # korelasi antar kolom
# Out:
# <ipython-input-19-cf4dae5cf903>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr() # korelasi antar kolom
#                Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed       1.000000  0.911309   0.892983  0.949722   0.892922
# Deaths          0.911309  1.000000   0.757676  0.891643   0.766139
# Recovered       0.892983  0.757676   1.000000  0.707918   0.806621
# Active          0.949722  0.891643   0.707918  1.000000   0.845328
# New cases       0.892922  0.766139   0.806621  0.845328   1.000000
# New deaths      0.597835  0.626369   0.508525  0.579172   0.730082
# New recovered   0.672535  0.548067   0.759875  0.530194   0.722974
#
#                New deaths  New recovered
# Confirmed        0.597835       0.672535
# Deaths           0.626369       0.548067
# Recovered        0.508525       0.759875
# Active           0.579172       0.530194
# New cases        0.730082       0.722974
# New deaths       1.000000       0.498003
# New recovered    0.498003       1.000000

# %% [markdown]
# Iris Dataset: Data Visualisation

# %%
import matplotlib.pyplot as plt # visualisasi data
import seaborn as sns # visualisasi data

# output dari visualisasi data akan diarahkan ke notebook
# %matplotlib inline

# %%
sns.heatmap(data=df.corr())
# Out:
# <ipython-input-21-afb2b4e09bbc>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr())
# <Axes: >

# %%
df['Deaths'].value_counts() # menghitung jumlah setiap species
# Out:
# 0        3855
# 1        1030
# 2         666
# 3         599
# 10        453
#          ...
# 3807        1
# 4125        1
# 4397        1
# 99952       1
# 45844       1
# Name: Deaths, Length: 3598, dtype: int64

# %%
df['Deaths'].value_counts() # menghitung jumlah setiap species
# Out:
# 0        3855
# 1        1030
# 2         666
# 3         599
# 10        453
#          ...
# 3807        1
# 4125        1
# 4397        1
# 99952       1
# 45844       1
# Name: Deaths, Length: 3598, dtype: int64

# %%
df['Deaths'].value_counts().plot.bar()
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x='Deaths')
plt.tight_layout()
# sns.countplot?

# %%
fig,ax = plt.subplots(nrows=2, ncols=2, figsize=(8,8))

df['Confirmed'].plot.line(ax=ax[0][0])
ax[0][0].set_title('Confirmed')

df['Deaths'].plot.line(ax=ax[0][1])
ax[0][1].set_title('Deaths')

df.Recovered.plot.line(ax=ax[1][0])
ax[1][0].set_title('Recovered')

df.Active.plot.line(ax=ax[1][1])
ax[1][1].set_title('Active')
# Out:
# Text(0.5, 1.0, 'Active')

# %%
df.plot()
plt.tight_layout()

# %%
df.hist(figsize=(6,6), bins=10)
plt.tight_layout()

# %%
df.boxplot()
plt.tight_layout()

# %%
sns.pairplot(df, hue='Deaths', markers='+')
plt.tight_layout()

# %% [markdown]
# Iris Dataset: Classification Models

# %%
from sklearn.model_selection import train_test_split # pembagi dataset menjadi training dan testing set
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report # evaluasi performa model

# %%
X = df.drop(columns='Deaths') # menempatkan features ke dalam variable X
X.head() # tampilkan 5 baris pertama
# Out:
#   Country/Region  Confirmed  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan          0          0       0          0           0
# 1        Albania          0          0       0          0           0
# 2        Algeria          0          0       0          0           0
# 3        Andorra          0          0       0          0           0
# 4         Angola          0          0       0          0           0
#
#    New recovered             WHO Region
# 0              0  Eastern Mediterranean
# 1              0                 Europe
# 2              0                 Africa
# 3              0                 Europe
# 4              0                 Africa

# %%
y = df['Deaths'] # menempatkan class label (target) ke dalam variabel y
y.head() # tampilkan 5 baris pertama
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Deaths, dtype: int64

# %%
# membagi dataset ke dalam training dan testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=10)

print('training dataset')
print(X_train.shape)
print(y_train.shape)
print()
print('testing dataset:')
print(X_test.shape)
print(y_test.shape)
# Out:
# training dataset
# (13902, 8)
# (13902,)
#
# testing dataset:
# (9268, 8)
# (9268,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k_range = list(range(1,15))
scores = []
for k in k_range:
    model_knn = KNeighborsClassifier(n_neighbors=k) # konfigurasi algoritma

# %%
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.svm import SVC
