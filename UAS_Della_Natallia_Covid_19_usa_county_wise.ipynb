# %% [markdown]
# <a href="https://colab.research.google.com/github/Della1122/Covid-19/blob/main/UAS_Della_Natallia_Covid_19_usa_county_wise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset country_wise_latest: Simple Exploratory Data Analysis (EDA)

# %%
import pandas as pd

# %%
#load package drive
from google.colab import drive

# %%
#memberikan akses kepada colab / Autorization
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#buat variabel jalur/dataset file dataset
dataset = '/content/drive/My Drive/dataset COVID 19/usa_county_wise.csv'

# %%
df = pd.read_csv('/content/drive/My Drive/dataset COVID 19/usa_county_wise.csv') # memuat file csv sebagai data frame

df.head() # tampilkan 5 baris pertama
# Out:
#         UID iso2 iso3  code3     FIPS    Admin2            Province_State  \
# 0        16   AS  ASM     16     60.0       NaN            American Samoa
# 1       316   GU  GUM    316     66.0       NaN                      Guam
# 2       580   MP  MNP    580     69.0       NaN  Northern Mariana Islands
# 3  63072001   PR  PRI    630  72001.0  Adjuntas               Puerto Rico
# 4  63072003   PR  PRI    630  72003.0    Aguada               Puerto Rico
#
#   Country_Region        Lat       Long_                  Combined_Key  \
# 0             US -14.271000 -170.132000            American Samoa, US
# 1             US  13.444300  144.793700                      Guam, US
# 2             US  15.097900  145.673900  Northern Mariana Islands, US
# 3             US  18.180117  -66.754367     Adjuntas, Puerto Rico, US
# 4             US  18.360255  -67.175131       Aguada, Puerto Rico, US
#
#       Date  Confirmed  Deaths
# 0  1/22/20          0       0
# 1  1/22/20          0       0
# 2  1/22/20          0       0
# 3  1/22/20          0       0
# 4  1/22/20          0       0

# %%
# Menghapus kolom yang tidak diperlukan
cols_to_drop = ['Country_Region', 'Confirmed', 'Deaths']
df.drop(columns=cols_to_drop, inplace=True)

# Menampilkan 5 baris pertama dari DataFrame
df.head()
# Out:
#         UID iso2 iso3  code3     FIPS    Admin2            Province_State  \
# 0        16   AS  ASM     16     60.0       NaN            American Samoa
# 1       316   GU  GUM    316     66.0       NaN                      Guam
# 2       580   MP  MNP    580     69.0       NaN  Northern Mariana Islands
# 3  63072001   PR  PRI    630  72001.0  Adjuntas               Puerto Rico
# 4  63072003   PR  PRI    630  72003.0    Aguada               Puerto Rico
#
#          Lat       Long_                  Combined_Key     Date
# 0 -14.271000 -170.132000            American Samoa, US  1/22/20
# 1  13.444300  144.793700                      Guam, US  1/22/20
# 2  15.097900  145.673900  Northern Mariana Islands, US  1/22/20
# 3  18.180117  -66.754367     Adjuntas, Puerto Rico, US  1/22/20
# 4  18.360255  -67.175131       Aguada, Puerto Rico, US  1/22/20

# %%
df.shape # bentuk/dimensi dataset (baris,kolom)
# Out:
# (627920, 11)

# %% [markdown]
# Berarti ada 187 baris dan 6 kolom

# %%
df.columns # daftar nama kolom
# Out:
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Lat', 'Long_', 'Combined_Key', 'Date'],
#       dtype='object')

# %%
df.dtypes # tipe data untuk tiap kolom
# Out:
# UID                 int64
# iso2               object
# iso3               object
# code3               int64
# FIPS              float64
# Admin2             object
# Province_State     object
# Lat               float64
# Long_             float64
# Combined_Key       object
# Date               object
# dtype: object

# %%
df.info() # informasi dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627920 entries, 0 to 627919
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   UID             627920 non-null  int64
#  1   iso2            627920 non-null  object
#  2   iso3            627920 non-null  object
#  3   code3           627920 non-null  int64
#  4   FIPS            626040 non-null  float64
#  5   Admin2          626792 non-null  object
#  6   Province_State  627920 non-null  object
#  7   Lat             627920 non-null  float64
#  8   Long_           627920 non-null  float64
#  9   Combined_Key    627920 non-null  object
#  10  Date            627920 non-null  object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 52.7+ MB

# %%
# df.isnull().values.any()
df.isna().values.any() # mendeteksi keberadaan nilai kosong
# Out:
# True

# %%
# df[df.duplicated(keep=False)] # tampilkan seluruh baris dengan duplikasi
df[df.duplicated()] # tampilkan hanya baris duplikasi sekunder
# Out:
# Empty DataFrame
# Columns: [UID, iso2, iso3, code3, FIPS, Admin2, Province_State, Lat, Long_, Combined_Key, Date]
# Index: []

# %%
df.duplicated().value_counts() # hitung jumlah duplikasi data
# Out:
# False    627920
# dtype: int64

# %%
df.drop_duplicates(inplace=True) # menghapus duplikasi data
df.shape
# Out:
# (627920, 11)

# %%
df.describe() # deskripsi data
# Out:
#                 UID          code3           FIPS            Lat  \
# count  6.279200e+05  627920.000000  626040.000000  627920.000000
# mean   8.342958e+07     834.491617   33061.684685      36.707212
# std    4.314702e+06      36.492620   18636.156825       9.061572
# min    1.600000e+01      16.000000      60.000000     -14.271000
# 25%    8.401811e+07     840.000000   19079.000000      33.895587
# 50%    8.402921e+07     840.000000   31014.000000      38.002344
# 75%    8.404612e+07     840.000000   47131.000000      41.573069
# max    8.410000e+07     850.000000   99999.000000      69.314792
#
#                Long_
# count  627920.000000
# mean      -88.601474
# std        21.715747
# min      -174.159600
# 25%       -97.790204
# 50%       -89.486710
# 75%       -82.311265
# max       145.673900

# %%
df.corr() # korelasi antar kolom
# Out:
# <ipython-input-30-cf4dae5cf903>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr() # korelasi antar kolom
#             UID     code3      FIPS       Lat     Long_
# UID    1.000000  0.903836 -0.198912  0.314965 -0.235989
# code3  0.903836  1.000000 -0.265912  0.341832 -0.195156
# FIPS  -0.198912 -0.265912  1.000000 -0.453129  0.483018
# Lat    0.314965  0.341832 -0.453129  1.000000 -0.721129
# Long_ -0.235989 -0.195156  0.483018 -0.721129  1.000000

# %% [markdown]
# Iris Dataset: Data Visualisation

# %%
import matplotlib.pyplot as plt # visualisasi data
import seaborn as sns # visualisasi data

# output dari visualisasi data akan diarahkan ke notebook
# %matplotlib inline

# %%
sns.heatmap(data=df.corr())
# Out:
# <ipython-input-32-afb2b4e09bbc>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x='Province_State')
plt.tight_layout()
# sns.countplot?

# %%
df['Province_State'].value_counts().plot.pie(autopct='%1.1f%%', labels=None, legend=True)
plt.tight_layout()
# Out:
# <ipython-input-39-f052dddb2531>:2: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
fig,ax = plt.subplots(nrows=2, ncols=2, figsize=(8,8))

df['UID'].plot.line(ax=ax[0][0])
ax[0][0].set_title('UID')

df['code3'].plot.line(ax=ax[0][1])
ax[0][1].set_title('code3')

df.FIPS.plot.line(ax=ax[1][0])
ax[1][0].set_title('FIPS')

df.Lat.plot.line(ax=ax[1][1])
ax[1][1].set_title('Lat')
# Out:
# Text(0.5, 1.0, 'Lat')

# %%
df.plot()
plt.tight_layout()

# %%
df.hist(figsize=(6,6), bins=10)
plt.tight_layout()

# %%
df.boxplot()
plt.tight_layout()

# %%
df.boxplot(by="Province_State", figsize=(8,8))
plt.tight_layout()

# %%
sns.pairplot(df, hue='Province_State', markers='+')
plt.tight_layout()

# %% [markdown]
# Iris Dataset: Classification Models

# %%
from sklearn.model_selection import train_test_split # pembagi dataset menjadi training dan testing set
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report # evaluasi performa model

# %%
X = df.drop(columns='Province_State') # menempatkan features ke dalam variable X
X.head() # tampilkan 5 baris pertama
# Out:
#         UID iso2 iso3  code3     FIPS    Admin2        Lat       Long_  \
# 0        16   AS  ASM     16     60.0       NaN -14.271000 -170.132000
# 1       316   GU  GUM    316     66.0       NaN  13.444300  144.793700
# 2       580   MP  MNP    580     69.0       NaN  15.097900  145.673900
# 3  63072001   PR  PRI    630  72001.0  Adjuntas  18.180117  -66.754367
# 4  63072003   PR  PRI    630  72003.0    Aguada  18.360255  -67.175131
#
#                    Combined_Key     Date
# 0            American Samoa, US  1/22/20
# 1                      Guam, US  1/22/20
# 2  Northern Mariana Islands, US  1/22/20
# 3     Adjuntas, Puerto Rico, US  1/22/20
# 4       Aguada, Puerto Rico, US  1/22/20

# %%
y = df['Province_State'] # menempatkan class label (target) ke dalam variabel y
y.head() # tampilkan 5 baris pertama
# Out:
# 0              American Samoa
# 1                        Guam
# 2    Northern Mariana Islands
# 3                 Puerto Rico
# 4                 Puerto Rico
# Name: Province_State, dtype: object

# %%
# membagi dataset ke dalam training dan testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=10)

print('training dataset')
print(X_train.shape)
print(y_train.shape)
print()
print('testing dataset:')
print(X_test.shape)
print(y_test.shape)
# Out:
# training dataset
# (376752, 10)
# (376752,)
#
# testing dataset:
# (251168, 10)
# (251168,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k_range = list(range(1,15))
scores = []
for k in k_range:
    model_knn = KNeighborsClassifier(n_neighbors=k) # konfigurasi algoritma

# %%
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.svm import SVC
