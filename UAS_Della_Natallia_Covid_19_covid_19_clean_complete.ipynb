# %% [markdown]
# <a href="https://colab.research.google.com/github/Della1122/Covid-19/blob/main/UAS_Della_Natallia_Covid_19_covid_19_clean_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset country_wise_latest: Simple Exploratory Data Analysis (EDA)

# %%
import pandas as pd

# %%
#load package drive
from google.colab import drive

# %%
#memberikan akses kepada colab / Autorization
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#buat variabel jalur/dataset file dataset
dataset = '/content/drive/My Drive/dataset COVID 19/covid_19_clean_complete.csv'

# %%
df = pd.read_csv('/content/drive/My Drive/dataset COVID 19/covid_19_clean_complete.csv') # memuat file csv sebagai data frame

df.head() # tampilkan 5 baris pertama
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
# Menghapus kolom yang tidak diperlukan (columns='Province/State')
cols_to_drop = ['Province/State']
df.drop(columns=cols_to_drop, inplace=True)

# Menampilkan 5 baris pertama dari DataFrame
df.head()
# Out:
#   Country/Region       Lat       Long        Date  Confirmed  Deaths  \
# 0    Afghanistan  33.93911  67.709953  2020-01-22          0       0
# 1        Albania  41.15330  20.168300  2020-01-22          0       0
# 2        Algeria  28.03390   1.659600  2020-01-22          0       0
# 3        Andorra  42.50630   1.521800  2020-01-22          0       0
# 4         Angola -11.20270  17.873900  2020-01-22          0       0
#
#    Recovered  Active             WHO Region
# 0          0       0  Eastern Mediterranean
# 1          0       0                 Europe
# 2          0       0                 Africa
# 3          0       0                 Europe
# 4          0       0                 Africa

# %%
df.shape # bentuk/dimensi dataset (baris,kolom)
# Out:
# (49068, 9)

# %% [markdown]
# Berarti ada 187 baris dan 6 kolom

# %%
df.columns # daftar nama kolom
# Out:
# Index(['Country/Region', 'Lat', 'Long', 'Date', 'Confirmed', 'Deaths',
#        'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
df.dtypes # tipe data untuk tiap kolom
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# WHO Region         object
# dtype: object

# %%
df.info() # informasi dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Confirmed       49068 non-null  int64
#  5   Deaths          49068 non-null  int64
#  6   Recovered       49068 non-null  int64
#  7   Active          49068 non-null  int64
#  8   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 3.4+ MB

# %%
# df.isnull().values.any()
df.isna().values.any() # mendeteksi keberadaan nilai kosong
# Out:
# False

# %%
# df[df.duplicated(keep=False)] # tampilkan seluruh baris dengan duplikasi
df[df.duplicated()] # tampilkan hanya baris duplikasi sekunder
# Out:
# Empty DataFrame
# Columns: [Country/Region, Lat, Long, Date, Confirmed, Deaths, Recovered, Active, WHO Region]
# Index: []

# %%
df.duplicated().value_counts() # hitung jumlah duplikasi data
# Out:
# False    49068
# dtype: int64

# %%
df.drop_duplicates(inplace=True) # menghapus duplikasi data
df.shape
# Out:
# (49068, 9)

# %%
df.describe() # deskripsi data
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
df.corr() # korelasi antar kolom
# Out:
# <ipython-input-25-cf4dae5cf903>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr() # korelasi antar kolom
#                 Lat      Long  Confirmed    Deaths  Recovered    Active
# Lat        1.000000 -0.127259   0.036665  0.070040   0.015329  0.044392
# Long      -0.127259  1.000000  -0.078911 -0.101340  -0.052391 -0.085688
# Confirmed  0.036665 -0.078911   1.000000  0.912361   0.895506  0.950255
# Deaths     0.070040 -0.101340   0.912361  1.000000   0.763090  0.891858
# Recovered  0.015329 -0.052391   0.895506  0.763090   1.000000  0.713088
# Active     0.044392 -0.085688   0.950255  0.891858   0.713088  1.000000

# %% [markdown]
# Iris Dataset: Data Visualisation

# %%
import matplotlib.pyplot as plt # visualisasi data
import seaborn as sns # visualisasi data

# output dari visualisasi data akan diarahkan ke notebook
# %matplotlib inline

# %%
sns.heatmap(data=df.corr())
# Out:
# <ipython-input-27-afb2b4e09bbc>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr())
# <Axes: >

# %%
df['Country/Region'].value_counts() # menghitung jumlah setiap species
# Out:
# China             6204
# Canada            2256
# France            2068
# United Kingdom    2068
# Australia         1504
#                   ...
# Holy See           188
# Honduras           188
# Hungary            188
# Iceland            188
# Lesotho            188
# Name: Country/Region, Length: 187, dtype: int64

# %%
df['Country/Region'].value_counts() # menghitung jumlah setiap species
# Out:
# China             6204
# Canada            2256
# France            2068
# United Kingdom    2068
# Australia         1504
#                   ...
# Holy See           188
# Honduras           188
# Hungary            188
# Iceland            188
# Lesotho            188
# Name: Country/Region, Length: 187, dtype: int64

# %%
df['Country/Region'].value_counts().plot.bar()
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x='Country/Region')
plt.tight_layout()
# sns.countplot?

# %%
df['Country/Region'].value_counts().plot.pie(autopct='%1.1f%%', labels=None, legend=True)
plt.tight_layout()
# Out:
# <ipython-input-32-8e3458d928db>:2: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
fig,ax = plt.subplots(nrows=2, ncols=2, figsize=(8,8))

df['Confirmed'].plot.line(ax=ax[0][0])
ax[0][0].set_title('Confirmed')

df['Deaths'].plot.line(ax=ax[0][1])
ax[0][1].set_title('Deaths')

df.Recovered.plot.line(ax=ax[1][0])
ax[1][0].set_title('Recovered')

df.Active.plot.line(ax=ax[1][1])
ax[1][1].set_title('Active')
# Out:
# Text(0.5, 1.0, 'Active')

# %%
df.plot()
plt.tight_layout()

# %%
df.hist(figsize=(6,6), bins=10)
plt.tight_layout()

# %%
df.boxplot()
plt.tight_layout()

# %%
df.boxplot(by="Country/Region", figsize=(8,8))
plt.tight_layout()

# %%
sns.pairplot(df, hue='Country/Region', markers='+')
plt.tight_layout()

# %% [markdown]
# Iris Dataset: Classification Models

# %%
from sklearn.model_selection import train_test_split # pembagi dataset menjadi training dan testing set
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report # evaluasi performa model

# %%
X = df.drop(columns='Country/Region') # menempatkan features ke dalam variable X
X.head() # tampilkan 5 baris pertama
# Out:
#         Lat       Long        Date  Confirmed  Deaths  Recovered  Active  \
# 0  33.93911  67.709953  2020-01-22          0       0          0       0
# 1  41.15330  20.168300  2020-01-22          0       0          0       0
# 2  28.03390   1.659600  2020-01-22          0       0          0       0
# 3  42.50630   1.521800  2020-01-22          0       0          0       0
# 4 -11.20270  17.873900  2020-01-22          0       0          0       0
#
#               WHO Region
# 0  Eastern Mediterranean
# 1                 Europe
# 2                 Africa
# 3                 Europe
# 4                 Africa

# %%
y = df['Country/Region'] # menempatkan class label (target) ke dalam variabel y
y.head() # tampilkan 5 baris pertama
# Out:
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# 3        Andorra
# 4         Angola
# Name: Country/Region, dtype: object

# %%
# membagi dataset ke dalam training dan testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=10)

print('training dataset')
print(X_train.shape)
print(y_train.shape)
print()
print('testing dataset:')
print(X_test.shape)
print(y_test.shape)
# Out:
# training dataset
# (29440, 8)
# (29440,)
#
# testing dataset:
# (19628, 8)
# (19628,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k_range = list(range(1,15))
scores = []
for k in k_range:
    model_knn = KNeighborsClassifier(n_neighbors=k) # konfigurasi algoritma

# %%
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.svm import SVC
