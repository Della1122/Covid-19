# %% [markdown]
# <a href="https://colab.research.google.com/github/Della1122/Covid-19/blob/main/UAS_Della_Natallia_Covid_19_day_wise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset country_wise_latest: Simple Exploratory Data Analysis (EDA)

# %%
import pandas as pd

# %%
#load package drive
from google.colab import drive

# %%
#memberikan akses kepada colab / Autorization
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#buat variabel jalur/dataset file dataset
dataset = '/content/drive/My Drive/day_wise.csv'

# %%
df = pd.read_csv('/content/drive/My Drive/dataset COVID 19/day_wise.csv') # memuat file csv sebagai data frame

df.head() # tampilkan 5 baris pertama
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# 2                   72.22                 9
# 3                  107.69                11
# 4                  107.69                13

# %%
# Menghapus kolom yang tidak diperlukan (columns='No. of countries')
cols_to_drop = ['No. of countries']
df.drop(columns=cols_to_drop, inplace=True)

# Menampilkan 5 baris pertama dari DataFrame
df.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered
# 0                   60.71
# 1                   60.00
# 2                   72.22
# 3                  107.69
# 4                  107.69

# %%
df.shape # bentuk/dimensi dataset (baris,kolom)
# Out:
# (188, 11)

# %% [markdown]
# Berarti ada 187 baris dan 6 kolom

# %%
df.columns # daftar nama kolom
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered'],
#       dtype='object')

# %%
df.dtypes # tipe data untuk tiap kolom
# Out:
# Date                       object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# dtype: object

# %%
df.info() # informasi dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 16.3+ KB

# %%
# df.isnull().values.any()
df.isna().values.any() # mendeteksi keberadaan nilai kosong
# Out:
# False

# %%
# df[df.duplicated(keep=False)] # tampilkan seluruh baris dengan duplikasi
df[df.duplicated()] # tampilkan hanya baris duplikasi sekunder
# Out:
# Empty DataFrame
# Columns: [Date, Confirmed, Deaths, Recovered, Active, New cases, New deaths, New recovered, Deaths / 100 Cases, Recovered / 100 Cases, Deaths / 100 Recovered]
# Index: []

# %%
df.duplicated().value_counts() # hitung jumlah duplikasi data
# Out:
# False    188
# dtype: int64

# %%
df.describe() # deskripsi data
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    1.121910e+05    3935.000000  6.044125e+04  5.864175e+04    5568.500000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# 75%    7.422046e+06  418634.500000  3.416396e+06  3.587015e+06  131502.500000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# mean   3478.824468   50362.015957            4.860638              34.343936
# std    2537.735652   56090.892479            1.579541              16.206159
# min       0.000000       0.000000            2.040000               1.710000
# 25%     250.750000    2488.250000            3.510000              22.785000
# 50%    4116.000000   30991.500000            4.850000              35.680000
# 75%    5346.000000   79706.250000            6.297500              48.945000
# max    9966.000000  284394.000000            7.180000              57.450000
#
#        Deaths / 100 Recovered
# count              188.000000
# mean                22.104521
# std                 22.568307
# min                  6.260000
# 25%                  9.650000
# 50%                 15.380000
# 75%                 25.342500
# max                134.430000

# %%
df.corr() # korelasi antar kolom
# Out:
# <ipython-input-16-cf4dae5cf903>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr() # korelasi antar kolom
#                         Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed                1.000000  0.975981   0.990165  0.986543   0.961473
# Deaths                   0.975981  1.000000   0.936940  0.996879   0.952450
# Recovered                0.990165  0.936940   1.000000  0.953981   0.936576
# Active                   0.986543  0.996879   0.953981  1.000000   0.967578
# New cases                0.961473  0.952450   0.936576  0.967578   1.000000
# New deaths               0.555479  0.625537   0.476217  0.637241   0.721846
# New recovered            0.944875  0.923130   0.935754  0.931824   0.928570
# Deaths / 100 Cases       0.221469  0.383897   0.096131  0.364250   0.367629
# Recovered / 100 Cases    0.720283  0.715555   0.711328  0.711695   0.670914
# Deaths / 100 Recovered  -0.400336 -0.410470  -0.382937 -0.410725  -0.405802
#
#                         New deaths  New recovered  Deaths / 100 Cases  \
# Confirmed                 0.555479       0.944875            0.221469
# Deaths                    0.625537       0.923130            0.383897
# Recovered                 0.476217       0.935754            0.096131
# Active                    0.637241       0.931824            0.364250
# New cases                 0.721846       0.928570            0.367629
# New deaths                1.000000       0.555759            0.774790
# New recovered             0.555759       1.000000            0.215238
# Deaths / 100 Cases        0.774790       0.215238            1.000000
# Recovered / 100 Cases     0.328203       0.684925            0.241877
# Deaths / 100 Recovered   -0.271905      -0.383327           -0.282469
#
#                         Recovered / 100 Cases  Deaths / 100 Recovered
# Confirmed                            0.720283               -0.400336
# Deaths                               0.715555               -0.410470
# Recovered                            0.711328               -0.382937
# Active                               0.711695               -0.410725
# New cases                            0.670914               -0.405802
# New deaths                           0.328203               -0.271905
# New recovered                        0.684925               -0.383327
# Deaths / 100 Cases                   0.241877               -0.282469
# Recovered / 100 Cases                1.000000               -0.750625
# Deaths / 100 Recovered              -0.750625                1.000000

# %% [markdown]
# Iris Dataset: Data Visualisation

# %%
import matplotlib.pyplot as plt # visualisasi data
import seaborn as sns # visualisasi data

# output dari visualisasi data akan diarahkan ke notebook
# %matplotlib inline

# %%
sns.heatmap(data=df.corr())
# Out:
# <ipython-input-18-afb2b4e09bbc>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr())
# <Axes: >

# %%
df['Confirmed'].value_counts() # menghitung jumlah setiap species
# Out:
# 555         1
# 6077978     1
# 5110064     1
# 5216964     1
# 5322253     1
#            ..
# 538666      1
# 603066      1
# 670723      1
# 730300      1
# 16480485    1
# Name: Confirmed, Length: 188, dtype: int64

# %%
df['Confirmed'].value_counts() # menghitung jumlah setiap species
# Out:
# 555         1
# 6077978     1
# 5110064     1
# 5216964     1
# 5322253     1
#            ..
# 538666      1
# 603066      1
# 670723      1
# 730300      1
# 16480485    1
# Name: Confirmed, Length: 188, dtype: int64

# %%
df['Confirmed'].value_counts().plot.bar()
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x='Confirmed')
plt.tight_layout()
# sns.countplot?

# %%
df['Confirmed'].value_counts().plot.pie(autopct='%1.1f%%', labels=None, legend=True)
plt.tight_layout()
# Out:
# <ipython-input-23-1972ca96dbf3>:2: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
fig,ax = plt.subplots(nrows=2, ncols=2, figsize=(8,8))

df['Confirmed'].plot.line(ax=ax[0][0])
ax[0][0].set_title('Confirmed')

df['Deaths'].plot.line(ax=ax[0][1])
ax[0][1].set_title('Deaths')

df.Recovered.plot.line(ax=ax[1][0])
ax[1][0].set_title('Recovered')

df.Active.plot.line(ax=ax[1][1])
ax[1][1].set_title('Active')
# Out:
# Text(0.5, 1.0, 'Active')

# %%
df.plot()
plt.tight_layout()

# %%
df.hist(figsize=(6,6), bins=10)
plt.tight_layout()

# %%
df.boxplot()
plt.tight_layout()

# %%
df.boxplot(by="Confirmed", figsize=(8,8))
plt.tight_layout()

# %%
sns.pairplot(df, hue='Confirmed', markers='+')
plt.tight_layout()

# %% [markdown]
# Iris Dataset: Classification Models

# %%
from sklearn.model_selection import train_test_split # pembagi dataset menjadi training dan testing set
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report # evaluasi performa model

# %%
X = df.drop(columns='Date') # menempatkan features ke dalam variable X
X.head() # tampilkan 5 baris pertama
# Out:
#    Confirmed  Deaths  Recovered  Active  New cases  New deaths  New recovered  \
# 0        555      17         28     510          0           0              0
# 1        654      18         30     606         99           1              2
# 2        941      26         36     879        287           8              6
# 3       1434      42         39    1353        493          16              3
# 4       2118      56         52    2010        684          14             13
#
#    Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered
# 0                3.06                   5.05                   60.71
# 1                2.75                   4.59                   60.00
# 2                2.76                   3.83                   72.22
# 3                2.93                   2.72                  107.69
# 4                2.64                   2.46                  107.69

# %%
y = df['Confirmed'] # menempatkan class label (target) ke dalam variabel y
y.head() # tampilkan 5 baris pertama
# Out:
# 0     555
# 1     654
# 2     941
# 3    1434
# 4    2118
# Name: Confirmed, dtype: int64

# %%
# membagi dataset ke dalam training dan testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=10)

print('training dataset')
print(X_train.shape)
print(y_train.shape)
print()
print('testing dataset:')
print(X_test.shape)
print(y_test.shape)
# Out:
# training dataset
# (112, 10)
# (112,)
#
# testing dataset:
# (76, 10)
# (76,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k_range = list(range(1,15))
scores = []
for k in k_range:
    model_knn = KNeighborsClassifier(n_neighbors=k) # konfigurasi algoritma

# %%
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.svm import SVC
